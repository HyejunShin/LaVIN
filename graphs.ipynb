    {"train_lr": 0.0005136598261448841, "train_closs": 0.01560321574800049, "epoch": 11},
    {"train_lr": 0.00041721800377171023, "train_closs": 0.01237324541428792, "epoch": 12},
    {"train_lr": 0.00032519050133769596, "train_closs": 0.009746659165429739, "epoch": 13},
    {"train_lr": 0.00024037352793613578, "train_closs": 0.007713401461831434, "epoch": 14},
    {"train_lr": 0.0001653442043843753, "train_closs": 0.0066591569232461135, "epoch": 15},
    {"train_lr": 0.00010238225871186679, "train_closs": 0.005138986304374254, "epoch": 16},
    {"train_lr": 5.3400757777586255e-05, "train_closs": 0.004249007614958144, "epoch": 17},
    {"train_lr": 1.988797970158711e-05, "train_closs": 0.0038199561579582604, "epoch": 18},
    {"train_lr": 2.8621932874244416e-06, "train_closs": 0.0036774916723042745, "epoch": 19}
]

# Data for decreasing drop probability v2
dec_drop_prob_v2_data = [
    {"train_lr": 0.0002805432308779627, "train_closs": 0.6716395273364467, "epoch": 0},
    {"train_lr": 0.0008430432308779624, "train_closs": 0.1670658247677655, "epoch": 1},
    {"train_lr": 0.0011221592815601764, "train_closs": 0.09972806411633171, "epoch": 2},
    {"train_lr": 0.001105175792338817, "train_closs": 0.07005163636655645, "epoch": 3},
    {"train_lr": 0.0010717033737744578, "train_closs": 0.05298117190917882, "epoch": 4},
    {"train_lr": 0.0010227590683672978, "train_closs": 0.043386575918689156, "epoch": 5},
    {"train_lr": 0.0009598300240701207, "train_closs": 0.035738051621363946, "epoch": 6},
    {"train_lr": 0.0008848283080502713, "train_closs": 0.03015717319877248, "epoch": 7},
    {"train_lr": 0.0008000328094963026, "train_closs": 0.024575353015300838, "epoch": 8},
    {"train_lr": 0.0007080199967231973, "train_closs": 0.020285156633327923, "epoch": 9},
    {"train_lr": 0.0006115856324863267, "train_closs": 0.01644028332681494, "epoch": 10},
    {"train_lr": 0.0005136598261448841, "train_closs": 0.013263173190622791, "epoch": 11},
    {"train_lr": 0.00041721800377171023, "train_closs": 0.010257131044854165, "epoch": 12},
    {"train_lr": 0.00032519050133769596, "train_closs": 0.008022368890845049, "epoch": 13},
    {"train_lr": 0.00024037352793613578, "train_closs": 0.0062327087206483864, "epoch": 14},
    {"train_lr": 0.0001653442043843753, "train_closs": 0.00489847596189198, "epoch": 15},
    {"train_lr": 0.00010238225871186679, "train_closs": 0.003950348539520254, "epoch": 16},
    {"train_lr": 5.3400757777586255e-05, "train_closs": 0.0032524490116678044, "epoch": 17},
    {"train_lr": 1.988797970158711e-05, "train_closs": 0.0029611188630350427, "epoch": 18},
    {"train_lr": 2.8621932874244416e-06, "train_closs": 0.0028058364097611997, "epoch": 19}
]

# %%
import matplotlib.pyplot as plt

def plot_train_closs(data, label):
    epochs = [entry["epoch"] for entry in data]
    train_closs = [entry["train_closs"] for entry in data]
    plt.plot(epochs, train_closs, label=label)

plt.figure(figsize=(8, 5))

# Plotting each dataset
plot_train_closs(base_data, "Base Data")
plot_train_closs(triangular2_lr_data, "Triangular2 LR Data")
plot_train_closs(step_lr_data, "Step LR Data")
plot_train_closs(exponential_lr_data, "Exponential LR Data")
plot_train_closs(inc_drop_prob_data, "Increasing Drop Probability Data")
plot_train_closs(dec_drop_prob_data, "Decreasing Drop Probability Data")
plot_train_closs(inc_drop_prob_v2_data, "Increasing Drop Probability V2 Data")
plot_train_closs(dec_drop_prob_v2_data, "Decreasing Drop Probability V2 Data")

# Adding labels and legend
plt.xlabel("Epoch")
plt.ylabel("Train Cross Entropy Loss")
plt.title("Train Cross Entropy Loss vs. Epoch")
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for overall accuracy
models = ['Base', 'Triangular2', 'Step', 'Exponential', 'IncDropProb', 'DecDropProb', 'IncDropProbV2', 'DecDropProbV2']
overall_accuracy = [88.82, 86.11, 87.13, 86.16, 87.17, 87.62, 87.46, 87.95]

# Data for different accuracy categories
categories = ['acc_natural', 'acc_social', 'acc_language', 'acc_has_text', 'acc_has_image', 'acc_no_context', 'acc_grade_1_6', 'acc_grade_7_12']
acc_data = {
    'Base': [88.45, 94.71, 84.82, 87.59, 86.37, 87.80, 90.20, 86.35],
    'Triangular2': [85.48, 92.58, 82.18, 84.51, 83.44, 84.88, 87.15, 84.25],
    'Step': [86.23, 94.15, 83.27, 85.34, 85.42, 86.48, 88.36, 84.90],
    'Exponential': [85.52, 93.59, 81.45, 84.51, 83.99, 84.88, 87.67, 83.45],
    'IncDropProb': [86.50, 93.03, 83.82, 85.78, 84.18, 86.69, 88.62, 84.57],
    'DecDropProb': [87.21, 94.60, 82.82, 86.22, 86.02, 86.27, 89.35, 84.51],
    'IncDropProbV2': [86.63, 94.15, 83.73, 85.63, 85.23, 87.25, 88.58, 85.43],
    'DecDropProbV2': [87.57, 94.15, 83.73, 86.51, 85.37, 87.11, 89.35, 85.43],
}

# Plotting overall accuracy bar graph
plt.figure(figsize=(8, 5))
plt.bar(models, overall_accuracy, color='skyblue')
plt.xlabel('Models')
plt.ylabel('Overall Accuracy (%)')
plt.title('Overall Accuracy Comparison of Different Models')
plt.ylim([85, 90])
plt.xticks(rotation=45)  # Rotate x-axis labels by 45 degrees
plt.show()

# Plotting bar graphs for different accuracy categories
for category in categories:
    plt.figure(figsize=(8, 5))
    plt.bar(models, [acc_data[model][categories.index(category)] for model in models], color='lightcoral')
    plt.xlabel('Models')
    plt.ylabel(f'Accuracy (%) for {category}')
    plt.title(f'{category} Accuracy Comparison of Different Models')
    plt.ylim([80, 95])
    plt.xticks(rotation=45)  # Rotate x-axis labels by 45 degrees
    plt.show()

# %%
# Extracting data for plotting
epochs = [entry["epoch"] for entry in base_data]
base_lr = [entry["train_lr"] for entry in base_data]
triangular2_lr = [entry["train_lr"] for entry in triangular2_lr_data]
step_lr = [entry["train_lr"] for entry in step_lr_data]
exponential_lr = [entry["train_lr"] for entry in exponential_lr_data]

# Plotting learning rates
plt.figure(figsize=(8, 5))
plt.plot(epochs, base_lr, label='Base', marker='o')
plt.plot(epochs, triangular2_lr, label='Triangular2', marker='o')
plt.plot(epochs, step_lr, label='Step', marker='o')
plt.plot(epochs, exponential_lr, label='Exponential', marker='o')

plt.xlabel('Epoch')
plt.ylabel('Learning Rate')
plt.title('Learning Rate Comparison for Different Models')
plt.legend()
plt.show()
